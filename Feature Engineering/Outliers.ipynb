# %% [markdown]
# ### 5 number Summary and Box Plot

# %%
## Minimum , Maximu , Median , Q1 , Q3 , IQR

# %%
import numpy as np

# %%
lst_mrks=[23,44,56,43,22,21,33,122,12,45,66,54,33,56,77,88,72]
minimum,Q1,median,Q3,maximum=np.quantile(lst_mrks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(12.0),
#  np.float64(33.0),
#  np.float64(45.0),
#  np.float64(66.0),
#  np.float64(122.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 33.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# np.float64(-16.5)

# %%
higher_fence
# Out:
# np.float64(115.5)

# %%
lst_mrks=[23,44,56,43,22,21,33,22,12,45,66,54,33,56,77,88,72]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_mrks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
